# %%
# Method 1 for check the Face detection model which i can make using Roboflow
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 17.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 54.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 70.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="YOUR_API_KEY"
")
project = rf.workspace().project("face-detection-r3nzm")
model = project.version(1).model

prediction = model.predict("baby.jpg")
print(prediction)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# {
#   "inference_id": "2ec402b3-80ba-4a6e-a88e-37b52ce3fd6a",
#   "time": 0.2603109920000861,
#   "image": {
#     "width": 3468,
#     "height": 4624
#   },
#   "predictions": [
#     {
#       "class": "Baby kumari",
#       "class_id": 7,
#       "confidence": 0.7071
#     }
#   ],
#   "top": "Baby kumari",
#   "confidence": 0.7071,
#   "image_path": "baby.jpg",
#   "prediction_type": "ClassificationModel"
# }

# %%
# Method 2 for check the Face detection model which i can make using Roboflow
# !pip install inference-sdk
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.2/65.2 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 25.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 MB 13.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.4/212.4 kB 19.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 4.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.12.0.88
#     Uninstalling opencv-python-4.12.0.88:
#       Successfully uninstalled opencv-python-4.12.0.88
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.13.2
#     Uninstalling aiohttp-3.13.2:
#       Successfully uninstalled aiohttp-3.13.2
# ...

# %%
# import the inference-sdk
from inference_sdk import InferenceHTTPClient

# initialize the client
CLIENT = InferenceHTTPClient(
    api_url="https://serverless.roboflow.com",
    api_key="YOUR_API_KEY"
)

# infer on a local image
result = CLIENT.infer("baby.jpg", model_id="face-detection-r3nzm/1")

# %%
import json
print(json.dumps(result , indent=4))
# Out:
# {
#     "inference_id": "10ad17e5-ab33-4718-abc1-730c72cf91dc",
#     "time": 0.2747348489938304,
#     "image": {
#         "width": 3468,
#         "height": 4624
#     },
#     "predictions": [
#         {
#             "class": "Baby kumari",
#             "class_id": 7,
#             "confidence": 0.7107
#         }
#     ],
#     "top": "Baby kumari",
#     "confidence": 0.7107
# }
